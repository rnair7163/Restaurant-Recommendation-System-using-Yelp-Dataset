# %%
import pandas as pd
import numpy as np

# %%
data_user = pd.read_csv('D:/yelp/users.csv',index_col = 0)
data_user.head()
data_review = pd.read_csv('D:/yelp/IL_review.csv',index_col = 0)
data_review.head()
# Out:
# D:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# D:\anaconda\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                 review_id                 user_id             business_id  \
# 0  m4AXzV9l14iFBd9DRdM82w  6X0i-oGUbh5DZdTHzFuKfg  9A1C1f0m4nQltQrOOTl-Kw
# 1  A-yKlSLEQQcoHR5q2lCyHg  Yximlvn0cfb3yVDaLuXDxw  VHsNB3pdGVcRgs6C3jt6Zg
# 2  asLnux3k2yqoVjcJcLuF0g  Cz8l7JQ2I_RhtK0BosH-7Q  Ah4i15g8Ow_zphzcpulTxQ
# 3  YIMS3PGxfWN5iFIIcYJHEg  m7rosN4Yh__tXkWP0_myqw  9MnbQg7kfb_WgxoV0hXKSQ
# 4  CWjzk0w-OZwzOmCut-6bvQ  iYwDTxhYStsIDHB514ltjA  t_yiQnxUDdPPCN2z4QyezA
#
#    stars  useful  funny  cool  \
# 0    1.0      11      1     0
# 1    5.0       1      0     0
# 2    4.0       0      0     0
# 3    5.0       1      0     0
# 4    5.0       1      0     1
#
#                                                 text                 date  \
# 0  The building is lovely.  The remodel after But...  2013-12-07 02:26:13
# 1  LOVE LOVE LOVE this place! I'm a bit of a suck...  2013-08-03 19:59:56
# 2  The bread company is perfect for lunch. The pr...  2015-12-05 05:38:55
# 3  This is the best restaurant under $30 per plat...  2015-06-21 01:54:38
# 4  If you want REAL, AUTHENTIC asian food, this i...  2015-09-23 23:23:51
#
#    year
# 0  2013
# 1  2013
# 2  2015
# 3  2015
# 4  2015

# %%
#filter the users from Illinois
unique_IL_users = data_review.user_id.unique()
user_idx = [i for i in range(data_user.shape[0]) if data_user.user_id[i] in unique_IL_users]
user_df = data_user.iloc[user_idx,:]
# Out:
# (12859, 22)

# %%
user_df.shape
user_df.head()
user_df.user_id.nunique()
# Out:
# 12859

# %%
len(unique_IL_users)
# Out:
# 12859

# %%
user_df[~user_df.user_id.isin(unique_IL_users)]
# Out:
# Empty DataFrame
# Columns: [user_id, name, review_count, yelping_since, useful, funny, cool, elite, friends, fans, average_stars, compliment_hot, compliment_more, compliment_profile, compliment_cute, compliment_list, compliment_note, compliment_plain, compliment_cool, compliment_funny, compliment_writer, compliment_photos]
# Index: []
#
# [0 rows x 22 columns]

# %%
user_df.head()
# Out:
#                     user_id     name  review_count        yelping_since  \
# 51   fcNU65OaCj7slBJ60VSQgw   Steven          1204  2007-07-08 16:56:40
# 54   4mjnkd8oJVCfBKN3i4rB-g   Tricia          1247  2008-11-27 02:24:47
# 96   ZdYHJ-hctaaDeH1CpP7-EA  Colleen           266  2009-08-08 16:46:46
# 297  JWgti_adPZywG9SKUbnB-w    Sarah           141  2007-11-12 02:56:43
# 303  PIzmdHF7p9GwXhwt3b3JxQ   Sasuke           112  2008-07-15 19:06:06
#
#      useful  funny  cool                                              elite  \
# 51     4907   2674  2718  2007,2008,2009,2010,2011,2012,2013,2014,2015,2016
# 54     3967   2631  2491  2009,2010,2011,2012,2013,2014,2015,2016,2017,2018
# 96      491    103   152                           2010,2011,2012,2013,2014
# 297     227     76    42                                               2015
# 303     154     57    35                                                NaN
#
#                                                friends  fans  ...  \
# 51   T-CVPEYAAJFWGzXaxSt8eg, zyhHd6AeavKVdOAXAPz-DQ...    89  ...
# 54   RO3vznPVVw5NWcgfP3k17A, azPMZoWkxdyjpnFul3aBQw...   141  ...
# 96   ouODopBKF3AqfCkuQEnrDg, QowYhZNL0T3UOi1FLG5VYQ...    11  ...
# 297  -X2qJ65I4Gz3UznpJqqS7Q, XrrXU5whFrQo_3wpiKhpaw...     1  ...
# 303  wPkrThYsvs-pii7Ac1Hk9w, nO4bSABjYmR3MVvVjC0EeQ...     7  ...
#
#      compliment_more  compliment_profile  compliment_cute  compliment_list  \
# 51                14                  12                6                4
# 54                26                  25               15               10
# 96                 4                   2                3                0
# 297                2                   0                0                0
# 303                3                   0                0                0
#
#      compliment_note  compliment_plain  compliment_cool  compliment_funny  \
# 51                79               141              183               183
# 54               127               236              227               227
# 96                14                16               17                17
# 297                5                 3                5                 5
# 303                3                 4                1                 1
#
#      compliment_writer  compliment_photos
# 51                  57                 12
# 54                 124                102
# 96                   5                  3
# 297                  2                  1
# 303                  4                  0
#
# [5 rows x 22 columns]

# %%
#fix the index
user_df.index = range(user_df.shape[0])
user_df.head()
# Out:
#                   user_id     name  review_count        yelping_since  useful  \
# 0  fcNU65OaCj7slBJ60VSQgw   Steven          1204  2007-07-08 16:56:40    4907
# 1  4mjnkd8oJVCfBKN3i4rB-g   Tricia          1247  2008-11-27 02:24:47    3967
# 2  ZdYHJ-hctaaDeH1CpP7-EA  Colleen           266  2009-08-08 16:46:46     491
# 3  JWgti_adPZywG9SKUbnB-w    Sarah           141  2007-11-12 02:56:43     227
# 4  PIzmdHF7p9GwXhwt3b3JxQ   Sasuke           112  2008-07-15 19:06:06     154
#
#    funny  cool                                              elite  \
# 0   2674  2718  2007,2008,2009,2010,2011,2012,2013,2014,2015,2016
# 1   2631  2491  2009,2010,2011,2012,2013,2014,2015,2016,2017,2018
# 2    103   152                           2010,2011,2012,2013,2014
# 3     76    42                                               2015
# 4     57    35                                                NaN
#
#                                              friends  fans  ...  \
# 0  T-CVPEYAAJFWGzXaxSt8eg, zyhHd6AeavKVdOAXAPz-DQ...    89  ...
# 1  RO3vznPVVw5NWcgfP3k17A, azPMZoWkxdyjpnFul3aBQw...   141  ...
# 2  ouODopBKF3AqfCkuQEnrDg, QowYhZNL0T3UOi1FLG5VYQ...    11  ...
# 3  -X2qJ65I4Gz3UznpJqqS7Q, XrrXU5whFrQo_3wpiKhpaw...     1  ...
# 4  wPkrThYsvs-pii7Ac1Hk9w, nO4bSABjYmR3MVvVjC0EeQ...     7  ...
#
#    compliment_more  compliment_profile  compliment_cute  compliment_list  \
# 0               14                  12                6                4
# 1               26                  25               15               10
# 2                4                   2                3                0
# 3                2                   0                0                0
# 4                3                   0                0                0
#
#    compliment_note  compliment_plain  compliment_cool  compliment_funny  \
# 0               79               141              183               183
# 1              127               236              227               227
# 2               14                16               17                17
# 3                5                 3                5                 5
# 4                3                 4                1                 1
#
#    compliment_writer  compliment_photos
# 0                 57                 12
# 1                124                102
# 2                  5                  3
# 3                  2                  1
# 4                  4                  0
#
# [5 rows x 22 columns]

# %%
#Check missing values
user_df.isnull().sum()
# Out:
# user_id                   0
# name                      0
# review_count              0
# yelping_since             0
# useful                    0
# funny                     0
# cool                      0
# elite                 11743
# friends                   0
# fans                      0
# average_stars             0
# compliment_hot            0
# compliment_more           0
# compliment_profile        0
# compliment_cute           0
# compliment_list           0
# compliment_note           0
# compliment_plain          0
# compliment_cool           0
# compliment_funny          0
# compliment_writer         0
# compliment_photos         0
# dtype: int64

# %%
user_df['is_elite'] = ~np.array(user_df.elite.isnull())
user_df.is_elite.describe()
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# count     12859
# unique        2
# top       False
# freq      11743
# Name: is_elite, dtype: object

# %%
# too many values, may be just take year.
len(user_df.yelping_since.unique())
# Out:
# 12859

# %%
# get the year
yr_ls = [eval(x.split('-')[0]) for x in user_df.yelping_since]
user_df['year'] = yr_ls
user_df
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                       user_id     name  review_count        yelping_since  \
# 0      fcNU65OaCj7slBJ60VSQgw   Steven          1204  2007-07-08 16:56:40
# 1      4mjnkd8oJVCfBKN3i4rB-g   Tricia          1247  2008-11-27 02:24:47
# 2      ZdYHJ-hctaaDeH1CpP7-EA  Colleen           266  2009-08-08 16:46:46
# 3      JWgti_adPZywG9SKUbnB-w    Sarah           141  2007-11-12 02:56:43
# 4      PIzmdHF7p9GwXhwt3b3JxQ   Sasuke           112  2008-07-15 19:06:06
# ...                       ...      ...           ...                  ...
# 12854  Qy4LuK2Fnhuvwlj4Np88RA    Chris             1  2015-03-02 21:37:10
# 12855  AKP1vt9eeyVISZYc2G0WOQ    Katie             7  2010-06-15 01:52:50
# 12856  YfVGrr7SqPI1NY-mx9jfUw      Liz             2  2018-03-19 22:18:34
# 12857  lcd1uiaw4sZd7wGxpHbd0w     Lisa             3  2014-08-03 22:23:27
# 12858  mSF19ZUrbwdYkdBF_4V2hQ   Kristi             9  2013-01-18 17:09:51
#
#        useful  funny  cool                                              elite  \
# 0        4907   2674  2718  2007,2008,2009,2010,2011,2012,2013,2014,2015,2016
# 1        3967   2631  2491  2009,2010,2011,2012,2013,2014,2015,2016,2017,2018
# 2         491    103   152                           2010,2011,2012,2013,2014
# 3         227     76    42                                               2015
# 4         154     57    35                                                NaN
# ...       ...    ...   ...                                                ...
# 12854       0      0     0                                                NaN
# 12855       2      0     1                                                NaN
# 12856       0      0     0                                                NaN
# 12857       4      1     0                                                NaN
# 12858       3      2     0                                                NaN
#
#                                                  friends  fans  ...  \
# 0      T-CVPEYAAJFWGzXaxSt8eg, zyhHd6AeavKVdOAXAPz-DQ...    89  ...
# 1      RO3vznPVVw5NWcgfP3k17A, azPMZoWkxdyjpnFul3aBQw...   141  ...
# 2      ouODopBKF3AqfCkuQEnrDg, QowYhZNL0T3UOi1FLG5VYQ...    11  ...
# 3      -X2qJ65I4Gz3UznpJqqS7Q, XrrXU5whFrQo_3wpiKhpaw...     1  ...
# 4      wPkrThYsvs-pii7Ac1Hk9w, nO4bSABjYmR3MVvVjC0EeQ...     7  ...
# ...                                                  ...   ...  ...
# 12854                                               None     0  ...
# 12855                                               None     0  ...
# 12856                                               None     0  ...
# 12857                                               None     0  ...
# 12858                                               None     0  ...
#
#        compliment_cute  compliment_list  compliment_note  compliment_plain  \
# 0                    6                4               79               141
# 1                   15               10              127               236
# 2                    3                0               14                16
# 3                    0                0                5                 3
# 4                    0                0                3                 4
# ...                ...              ...              ...               ...
# 12854                0                0                0                 0
# 12855                0                0                0                 0
# 12856                0                0                0                 0
# 12857                0                0                0                 0
# 12858                0                0                0                 0
#
#        compliment_cool  compliment_funny  compliment_writer  \
# 0                  183               183                 57
# 1                  227               227                124
# 2                   17                17                  5
# 3                    5                 5                  2
# 4                    1                 1                  4
# ...                ...               ...                ...
# 12854                0                 0                  0
# 12855                0                 0                  0
# 12856                0                 0                  0
# 12857                0                 0                  0
# 12858                0                 0                  0
#
#        compliment_photos  is_elite  year
# 0                     12      True  2007
# 1                    102      True  2008
# 2                      3      True  2009
# 3                      1      True  2007
# 4                      0     False  2008
# ...                  ...       ...   ...
# 12854                  0     False  2015
# 12855                  0     False  2010
# 12856                  0     False  2018
# 12857                  0     False  2014
# 12858                  0     False  2013
#
# [12859 rows x 24 columns]

# %%
user_df.to_csv("D:/yelp/IL_users.csv")
